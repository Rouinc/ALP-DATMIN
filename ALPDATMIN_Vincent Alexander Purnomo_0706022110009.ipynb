# %%
import pandas as pd

file = "data.csv"
df = pd.read_csv(file)

print(df.head())
# Out:
#   Marital status;Application mode;Application order;Course;"Daytime/evening attendance\t";Previous qualification;Previous qualification (grade);Nacionality;Mother's qualification;Father's qualification;Mother's occupation;Father's occupation;Admission grade;Displaced;Educational special needs;Debtor;Tuition fees up to date;Gender;Scholarship holder;Age at enrollment;International;Curricular units 1st sem (credited);Curricular units 1st sem (enrolled);Curricular units 1st sem (evaluations);Curricular units 1st sem (approved);Curricular units 1st sem (grade);Curricular units 1st sem (without evaluations);Curricular units 2nd sem (credited);Curricular units 2nd sem (enrolled);Curricular units 2nd sem (evaluations);Curricular units 2nd sem (approved);Curricular units 2nd sem (grade);Curricular units 2nd sem (without evaluations);Unemployment rate;Inflation rate;GDP;Target
# 0  1;17;5;171;1;1;122.0;1;19;12;5;9;127.3;1;0;0;1...
# 1  1;15;1;9254;1;1;160.0;1;1;3;3;3;142.5;1;0;0;0;...
# ...

# %%
import pandas as pd

file = "data.csv"
df = pd.read_csv(file, delimiter=';')

print(df.head())
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x='Marital status', data=df)
plt.show()

# %%
df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# ...

# %%
column = 'Age at enrollment'
plt.figure(figsize=(10, 6))
sns.histplot(df[column], bins=20, kde=True)
plt.title(f'Distribution of {column}')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.regplot(x='Age at enrollment', y='Admission grade', data=df)
plt.title('Relationship between Age at Enrollment and Admission Grade')
plt.show()

# %%
relationship_table = pd.crosstab(df['Marital status'], df['International'])
relationship_table.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Relationship between Marital Status and International Status')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='International', y='Admission grade', data=df)
plt.title('Relationship between International Status and Admission Grade')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='International', y='Course', data=df)
plt.title('Relationship between International and Course with Bar Plot')
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

features_for_clustering = ['Age at enrollment', 'Admission grade', 'GDP']
X = df[features_for_clustering]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), inertia, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.show()

# %%
optimal_k = 3

kmeans = KMeans(n_clusters=optimal_k, random_state=42)
df['KMeans_Cluster'] = kmeans.fit_predict(X_scaled)

sns.pairplot(df, hue='KMeans_Cluster', palette='Set1', vars=features_for_clustering)
plt.show()

# %%
import seaborn as sns
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

agg_cluster = AgglomerativeClustering(n_clusters=optimal_k, linkage='ward')
df['Hierarchical_Cluster'] = agg_cluster.fit_predict(X_scaled)

linked = linkage(X_scaled, 'ward')
plt.figure(figsize=(12, 8))
dendrogram(linked, orientation='top', distance_sort='descending', show_leaf_counts=True)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Cluster Size')
plt.show()

sns.pairplot(df, hue='Hierarchical_Cluster', palette='Set1', vars=features_for_clustering)
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

target_variable = 'Target'

features = df.drop([target_variable, 'KMeans_Cluster', 'Hierarchical_Cluster'], axis=1)  # Remove clustering results
target = df[target_variable]


X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)


classifier = RandomForestClassifier(random_state=42)
classifier.fit(X_train, y_train)


y_pred = classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)


print(f"Accuracy: {accuracy:.4f}")
print("\nConfusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# Accuracy: 0.7605
#
# Confusion Matrix:
# [[243  23  50]
#  [ 35  45  71]
#  [  9  24 385]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Dropout       0.85      0.77      0.81       316
#     Enrolled       0.49      0.30      0.37       151
#     Graduate       0.76      0.92      0.83       418
#
#     accuracy                           0.76       885
#    macro avg       0.70      0.66      0.67       885
# weighted avg       0.75      0.76      0.74       885
